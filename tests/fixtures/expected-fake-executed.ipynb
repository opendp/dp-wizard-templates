# %%
# %pip install pytest

# %% [markdown]
# Should be markdown

# %% [markdown]
# Should be markdown (details)

# %%
# Should be code
print("2 + 2")
# Out:
# 2 + 2

# %%
# Should be code (details)
print(2 + 2)
# Out:
# 4
